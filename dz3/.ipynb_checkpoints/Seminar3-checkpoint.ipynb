# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(0,10,0.001)
s = np.sin(2*np.pi*t)+np.sin(2*np.pi*t/2-np.pi/4)
plt.plot(t,s)

# %%
n = np.random.uniform(np.min(s)/3, np.max(s)/3, len(t))
sn = s+n
plt.plot(t,sn)
plt.plot(t,s)

# %%
print(np.min(s)/10, np.max(s)/10, len(t))
# Out:
# -0.2 0.11249965672087192 10000

# %%
fil = np.ones(100)

s_for_conv = np.ones(len(s)+2*len(fil)//2-1)
s_for_conv[len(fil)//2:len(fil)//2+len(s)] = sn
print(len(s_for_conv))
# Out:
# 10099

# %%
s_matrix = []
for i in range(len(s)):
    s_matrix.append(s_for_conv[i:i+len(fil)])
print(len(s_matrix))
s_matrix = np.array(s_matrix)
print(s_matrix.shape)
# Out:
# 10000
# (10000, 100)

# %%
c = np.linalg.lstsq(s_matrix, s)
print(c[0])
# Out:
# [0.0049364  0.00451668 0.00420897 0.00414981 0.00412213 0.00400475
#  0.00413449 0.00423204 0.00453568 0.00478437 0.00463931 0.00498346
#  0.00517565 0.00500573 0.00534276 0.00505169 0.00556573 0.00537197
#  0.00544079 0.00541666 0.00570923 0.00598909 0.00653655 0.00689811
#  0.00732596 0.00784816 0.00782303 0.007854   0.00805594 0.00813292
#  0.00860221 0.00872696 0.00955219 0.00990114 0.01079008 0.01128416
#  0.0119559  0.01290507 0.01322612 0.0139552  0.0151846  0.01586084
#  0.01716825 0.0184108  0.01913436 0.02023934 0.0210613  0.02227227
#  0.02368824 0.02510727 0.02664318 0.02500756 0.02394037 0.02246928
#  0.02109826 0.01984991 0.01857313 0.01784616 0.01696782 0.01609923
#  0.01526312 0.01424089 0.01359827 0.01251632 0.01230622 0.01172422
#  0.01127439 0.01136355 0.01054718 0.01004656 0.009311   0.00852401
#  0.00771778 0.00767042 0.00745624 0.00725702 0.00740509 0.00719432
#  0.00686059 0.00606598 0.00586188 0.00541041 0.00552851 0.00564532
#  0.00537677 0.00571834 0.00554063 0.00539074 0.00555317 0.00524839
#  0.00495451 0.0052567  0.00480552 0.00451451 0.00494795 0.00470044
#  0.00499176 0.00466434 0.00465309 0.00442716]
# C:\Users\Sudogrenki\AppData\Local\Temp\ipykernel_1044\1955328950.py:1: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   c = np.linalg.lstsq(s_matrix, s)

# %%
s_filt = s_matrix @ c[0]#[::-1]
plt.plot(t, sn, label = 'sn')
plt.plot(t, s_filt, label = 's_filt')
plt.legend()

# %%
plt.hist(sn)
plt.hist(s)
# Out:
# (array([1145.,  510.,  420.,  370.,  370.,  370., 1535., 1270., 1310.,
#         2700.]),
#  array([-2.        , -1.68750034, -1.37500069, -1.06250103, -0.75000137,
#         -0.43750172, -0.12500206,  0.1874976 ,  0.49999725,  0.81249691,
#          1.12499657]),
#  <BarContainer object of 10 artists>)

# %%
def update(x, y, n):

    e = y - x

# %%
for i in range(len(s_matrix)):

    e = s_matrix[i] - fil @ s_matrix[i]
    e /= np.max(e)
    e -= n[i:i+len(fil)]

    c = np.linalg.lstsq(e, n[i:i+len(fil)])

    print(c)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[11], line 7
#       4 e /= np.max(e)
#       5 e -= n[i:i+len(fil)]
# ----> 7 c = np.linalg.lstsq(e, n[i:i+len(fil)])
#       9 print(c)
#
# File <__array_function__ internals>:200, in lstsq(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:2252, in lstsq(a, b, rcond)
#    2250 if is_1d:
#    2251     b = b[:, newaxis]
# -> 2252 _assert_2d(a, b)
#    2253 m, n = a.shape[-2:]
#    2254 m2, n_rhs = b.shape[-2:]
#
# File ~\anaconda3\Lib\site-packages\numpy\linalg\linalg.py:177, in _assert_2d(*arrays)
#     175 for a in arrays:
#     176     if a.ndim != 2:
# --> 177         raise LinAlgError('%d-dimensional array given. Array must be '
#     178                 'two-dimensional' % a.ndim)
#
# LinAlgError: 1-dimensional array given. Array must be two-dimensional
